# %%
import pandas as pd

# %%
SEP = pd.read_csv('C:/Temp/CALL_HOSP_09MONTH.csv')
OCT = pd.read_csv('C:/Temp/CALL_HOSP_10MONTH.csv') 
NOV = pd.read_csv('C:/Temp/CALL_HOSP_11MONTH.csv')
DEC = pd.read_csv('C:/Temp/CALL_HOSP_12MONTH.csv')

# %%
row_concat = pd.concat([SEP.loc[SEP["발신지_시도"] == "서울특별시"],OCT.loc[OCT["발신지_시도"] == "서울특별시"],NOV.loc[NOV["발신지_시도"] == "서울특별시"],DEC.loc[DEC["발신지_시도"] == "서울특별시"]]) 
row_concat.head()
# Out:
#            일자 요일 성별   연령 발신지_시도 발신지_구 발신지_읍면동  통화건수
# 99   20180901  토  남  10대  서울특별시   강남구     논현동     5
# 100  20180901  토  남  10대  서울특별시   강남구     역삼동     7
# 101  20180901  토  남  20대  서울특별시   강남구     논현동    52
# 102  20180901  토  남  20대  서울특별시   강남구     수서동     5
# 103  20180901  토  남  20대  서울특별시   강남구     일원동     5

# %%
row_concat.to_csv('0912.csv', encoding='cp949')

# %%
Weather = pd.read_csv("C:/Temp/weather2018.csv", encoding='CP949')

# %%
WeatherInfo = pd.read_csv("C:/Temp/weatherinfo.csv", encoding='CP949')

# %%
WeatherInfo2 = WeatherInfo[['지점','지점명','위도','경도']]
Weather2 = pd.merge(Weather, WeatherInfo2 , on="지점")

# %%
Weather2.to_csv('Weather_2018.csv',encoding = 'cp949')

# %%
Weather = pd.read_csv("C:/Temp/Weather_2018.csv", encoding='CP949')

# %%
Weather.groupby("지점명").count()
# Out:
#        Unnamed: 0    지점    일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 지점명
# 강남           1092  1092  1092      1089      1089           1089      1089
# 강동            730   730   730       728       728            728       728
# 강북            730   730   730       726       726            726       726
# 강서            730   730   730       726       724            724       724
# 관악           1095  1095  1095      1092      1092           1092      1092
# 광진           1092  1092  1092      1086      1086           1086      1086
# 구로           1095  1095  1095      1082      1085           1085      1085
# 금천            730   730   730       716       718            718       718
# 기상청           730   730   730       728       724            724       724
# 남현            365   365   365       364       364            364       364
# 노원            730   730   730       728       728            728       728
# ...

# %% [markdown]
# -------------------------------------------------------------------------------------

# %%
data1 = pd.read_csv('C:/Temp/0104.csv',encoding = 'cp949',parse_dates=['일자'])
data2 = pd.read_csv('C:/Temp/0508.csv',encoding = 'cp949',parse_dates=['일자'])
data3 = pd.read_csv('C:/Temp/0912.csv',encoding = 'cp949',parse_dates=['일자'])

# %%
data = pd.concat([data1,data2,data3])

# %%
data2 = data.groupby(["일자","발신지_구"]).mean()

# %%
data2.head()
# Out:
#                   Unnamed: 0       통화건수
# 일자         발신지_구
# 2018-01-01 강남구     113.50000   9.011905
#            강동구     178.00000  11.022222
#            강북구     270.50000  20.062500
#            강서구     341.71875  17.328125
#            관악구    1026.50000   5.750000

# %%
data3 = data.groupby(["일자"]).mean()
data3 = data3["통화건수"]
data3 = pd.DataFrame(data3)

# %%
data3.tail()
# Out:
#                  통화건수
# 일자
# 2018-12-27  13.469680
# 2018-12-28  13.309111
# 2018-12-29   9.661644
# 2018-12-30   5.301829
# 2018-12-31  14.488959

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = 'nanummyeongjo'
plt.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots(figsize=(20, 8))
ax = data3.plot(ax=ax) 
plt.show()

# %%
data4 = data.groupby(["요일","발신지_구"]).mean()
data4.head()
# Out:
#              Unnamed: 0       통화건수
# 요일 발신지_구
# 금  강남구    204418.234836  61.576318
#    강동구    206149.064818  32.782936
#    강북구    205157.891377  64.751960
#    강서구    204477.247765  47.559132
#    관악구    209016.537069  82.537931

# %%
data4 = data.groupby(["요일"]).mean()
data4 = data4["통화건수"]
data4 = pd.DataFrame(data4)
data4.head()
# Out:
#          통화건수
# 요일
# 금   30.873699
# 목   29.826689
# 수   29.597017
# 월   36.334495
# 일    7.682195

# %%
data4['요일']=data4.index

# %%
import seaborn as sns
ax = plt.subplots() 
ax = sns.barplot(x='요일', y='통화건수', data=data4)

# %%
import pandas as pd
from sklearn.datasets import load_boston
boston = load_boston()
df = pd.DataFrame(boston.data, columns=boston.feature_names)
target_df = pd.Series(boston.target)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
